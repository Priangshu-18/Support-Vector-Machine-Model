# %% [markdown]
# <a href="https://colab.research.google.com/github/Priangshu-18/Support-Vector-Machine-Model/blob/main/Support_Vactor_Machine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Support Vector Machine Model**

# %% [markdown]
# ![support-vector-machine-algorithm.png](data:image/png;base64,...)

# %% [markdown]
# Equation of Hyperplane
#     y = wx + b

# %% [markdown]
# ![53314Support+vector+machines.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![R (1).png](data:image/png;base64,...)
